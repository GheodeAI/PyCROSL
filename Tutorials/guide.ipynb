# %% [markdown]
# # DPCRO_SL Guide

# %%
import sys
sys.path.insert(0, "..")

from PyCROSL.CRO_SL import *
from PyCROSL.AbsObjectiveFunc import *
from PyCROSL.SubstrateReal import *

# %% [markdown]
# The first step will be to define the objective function that will be optimized, this will be done taking as a base the class AbsObjectiveFunc.
# In this case, we will optimize a very simple function, simply adding the squared components of the vector.

# %%
"""
All the following methods will have to be implemented for the algorithm to work properly
with the same inputs, except for the constructor 
"""
class NoisySumSquare(AbsObjectiveFunc):
    """
    This is the constructor of the class, here is where the objective function can be setted up.
    In this case we will only add the size of the vector as a parameter.
    """
    def __init__(self, size, noise_level=1e-3):
        self.size = size
        self.opt = "min" # it can be "max" or "min"
        self.sup_lim = np.full(size, 100) # array where each component indicates the maximum value of the component of the vector
        self.inf_lim = np.full(size, -100) # array where each component indicates the minimum value of the component of the vector

        self.noise_level = noise_level

        # we call the constructor of the superclass with the size of the vector
        # and wether we want to maximize or minimize the function 
        super().__init__(self.size, self.opt, self.sup_lim, self.inf_lim, name="Noisy sphere")
    
    """
    This will be the objective function, that will recieve a vector and output a number
    """
    def objective(self, solution):
        return (solution**2).sum() + self.noise_level * np.random.random()
    
    """
    This will be the function used to generate random vectorsfor the initializatio of the algorithm
    """
    def random_solution(self):
        return (self.sup_lim - self.inf_lim)*np.random.random(self.size) + self.inf_lim
    
    """
    This will be the function that will repair solutions, or in other words, makes a solution
    outside the domain of the function into a valid one.
    If this is not needed simply return "solution"
    """
    def repair_solution(self, solution):
        return np.clip(solution, self.inf_lim, self.sup_lim)

# %%
objfunc = NoisySumSquare(30, noise_level=1e-5)

# %% [markdown]
# Now that we have our objective function, we can proceed to initialize the optimization algorithm.

# %% [markdown]
# First, we configure the hyperparameters of the algorithm in a dictionary, a detailed list of the parameters needed can be found on the README.md file. Here we use a configuration that should work ok in most cases.

# %%
params = {
    "popSize": 100,
    "rho": 0.6,
    "Fb": 0.98,
    "Fd": 0.2,
    "Pd": 0.8,
    "k": 3,
    "K": 20,
    "group_subs": True,

    "stop_cond": "Neval or convergence",
    "time_limit": 4000.0,
    "Ngen": 10000,
    "Neval": 3e5,
    "fit_target": 1000,
    "max_patience": 500,

    "verbose": True,
    "v_timer": 1,
    "Njobs": 1,

    "dynamic": True,
    "dyn_method": "success",
    "dyn_metric": "avg",
    "dyn_steps": 10,
    "prob_amp": 0.01
}

# %% [markdown]
# Since this algorithm relies on the mixing of different mutation and recombination operators, we will create the list of operators to be used. To create an operator we create an instance of the class SubstrateReal in case we are working with real valued vectors, and SubstrateInt if we are working with discrete valued vectors.
#
# Each operator has it's own parameters that will be specified in the creation of the operator

# %%
operators = [
    SubstrateReal("DE/rand/1", {"F": 0.7, "Cr":0.8}),
    SubstrateReal("DE/best/2", {"F": 0.7, "Cr":0.8}),
    SubstrateReal("DE/current-to-best/1", {"F": 0.7, "Cr":0.8}),
    SubstrateReal("DE/current-to-rand/1", {"F": 0.7, "Cr":0.8})
]

# %% [markdown]
# Now we simply create an instance of the CRO_SL algorithm with the previous data.

# %%
cro_alg = CRO_SL(objfunc, operators, params)

# %% [markdown]
# And we call the optimize function to find a suitable solution. This function will return the best solution along with its value in the objective function

# %%
solution, obj_value = cro_alg.optimize()
# Out:
# Starting optimization of Noisy sphere
# -------------------------------------
#
# Optimizing Noisy sphere:
# 	Time Spent: 0.0s
# 	Generation: 0
# 	Best fitness: 62799.25632992041
# 	Evaluations of fitness: 60
# 	Iterations without improvement: 0
# 	Substrate probability:
# 		DE/rand/1:           0.25
# 		DE/best/2:           0.25
# 		DE/current-to-best/1:0.25
# 		DE/current-to-rand/1:0.25
#
# Optimizing Noisy sphere:
# 	Time Spent: 1.0s
# 	Generation: 203
# 	Best fitness: 12233.88970374945
# 	Evaluations of fitness: 16923
# 	Iterations without improvement: 14
# 	Substrate probability:
# 		DE/rand/1:           0.005314
# 		DE/best/2:           0.982901
# 		DE/current-to-best/1:0.006852
# 		DE/current-to-rand/1:0.004933
#
# Optimizing Noisy sphere:
# 	Time Spent: 2.0s
# 	Generation: 332
# 	Best fitness: 3511.0509915911966
# 	Evaluations of fitness: 27565
# 	Iterations without improvement: 21
# 	Substrate probability:
# 		DE/rand/1:           0.005314
# 		DE/best/2:           0.982901
# 		DE/current-to-best/1:0.006852
# 		DE/current-to-rand/1:0.004933
#
# Optimizing Noisy sphere:
# 	Time Spent: 3.01s
# 	Generation: 446
# 	Best fitness: 89.59676381565612
# 	Evaluations of fitness: 36980
# 	Iterations without improvement: 2
# 	Substrate probability:
# 		DE/rand/1:           0.527856
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.258324
# 		DE/current-to-rand/1:0.208917
#
# Optimizing Noisy sphere:
# 	Time Spent: 4.02s
# 	Generation: 543
# 	Best fitness: 1.1456135810300658
# 	Evaluations of fitness: 44947
# 	Iterations without improvement: 3
# 	Substrate probability:
# 		DE/rand/1:           0.527856
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.258324
# 		DE/current-to-rand/1:0.208917
#
# Optimizing Noisy sphere:
# 	Time Spent: 5.03s
# 	Generation: 624
# 	Best fitness: 0.0876869017934682
# 	Evaluations of fitness: 51646
# 	Iterations without improvement: 0
# 	Substrate probability:
# 		DE/rand/1:           0.527856
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.258324
# 		DE/current-to-rand/1:0.208917
#
# Optimizing Noisy sphere:
# 	Time Spent: 6.04s
# 	Generation: 702
# 	Best fitness: 0.003917070742775274
# 	Evaluations of fitness: 58108
# 	Iterations without improvement: 1
# 	Substrate probability:
# 		DE/rand/1:           0.527856
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.258324
# 		DE/current-to-rand/1:0.208917
#
# Optimizing Noisy sphere:
# 	Time Spent: 7.04s
# 	Generation: 772
# 	Best fitness: 0.001515569972173967
# 	Evaluations of fitness: 63877
# 	Iterations without improvement: 20
# 	Substrate probability:
# 		DE/rand/1:           0.004902
# 		DE/best/2:           0.985292
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 8.05s
# 	Generation: 839
# 	Best fitness: 0.0011536667558181269
# 	Evaluations of fitness: 69425
# 	Iterations without improvement: 8
# 	Substrate probability:
# 		DE/rand/1:           0.004902
# 		DE/best/2:           0.985292
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 9.05s
# 	Generation: 901
# 	Best fitness: 0.0005340907045389289
# 	Evaluations of fitness: 74554
# 	Iterations without improvement: 28
# 	Substrate probability:
# 		DE/rand/1:           0.004902
# 		DE/best/2:           0.985292
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 10.07s
# 	Generation: 961
# 	Best fitness: 0.0003535415588316259
# 	Evaluations of fitness: 79518
# 	Iterations without improvement: 26
# 	Substrate probability:
# 		DE/rand/1:           0.004902
# 		DE/best/2:           0.985292
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 11.07s
# 	Generation: 1017
# 	Best fitness: 0.0002456334800159428
# 	Evaluations of fitness: 84168
# 	Iterations without improvement: 3
# 	Substrate probability:
# 		DE/rand/1:           0.004902
# 		DE/best/2:           0.985292
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 12.09s
# 	Generation: 1071
# 	Best fitness: 0.00016105108059661545
# 	Evaluations of fitness: 88637
# 	Iterations without improvement: 37
# 	Substrate probability:
# 		DE/rand/1:           0.004902
# 		DE/best/2:           0.985292
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 13.11s
# 	Generation: 1124
# 	Best fitness: 2.8982034901706655e-05
# 	Evaluations of fitness: 93012
# 	Iterations without improvement: 1
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 14.11s
# 	Generation: 1174
# 	Best fitness: 7.685084590961845e-06
# 	Evaluations of fitness: 97136
# 	Iterations without improvement: 6
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 15.13s
# 	Generation: 1223
# 	Best fitness: 2.9718382609512586e-06
# 	Evaluations of fitness: 101200
# 	Iterations without improvement: 10
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 16.15s
# 	Generation: 1270
# 	Best fitness: 2.424827686546191e-06
# 	Evaluations of fitness: 105072
# 	Iterations without improvement: 5
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 17.16s
# 	Generation: 1315
# 	Best fitness: 1.7184613372789434e-06
# 	Evaluations of fitness: 108790
# 	Iterations without improvement: 17
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 18.17s
# 	Generation: 1357
# 	Best fitness: 1.0743505446860692e-06
# 	Evaluations of fitness: 112281
# 	Iterations without improvement: 2
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 19.17s
# 	Generation: 1398
# 	Best fitness: 1.0743505446860692e-06
# 	Evaluations of fitness: 115669
# 	Iterations without improvement: 43
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 20.18s
# 	Generation: 1440
# 	Best fitness: 9.455556289815258e-07
# 	Evaluations of fitness: 119116
# 	Iterations without improvement: 24
# 	Substrate probability:
# 		DE/rand/1:           0.266984
# 		DE/best/2:           0.004902
# 		DE/current-to-best/1:0.341367
# 		DE/current-to-rand/1:0.386747
#
# Optimizing Noisy sphere:
# 	Time Spent: 21.18s
# 	Generation: 1480
# 	Best fitness: 9.455556289815258e-07
# 	Evaluations of fitness: 122440
# 	Iterations without improvement: 64
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 22.19s
# 	Generation: 1517
# 	Best fitness: 9.455556289815258e-07
# 	Evaluations of fitness: 125512
# 	Iterations without improvement: 101
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 23.22s
# 	Generation: 1555
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 128660
# 	Iterations without improvement: 12
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 24.23s
# 	Generation: 1591
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 131629
# 	Iterations without improvement: 48
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 25.25s
# 	Generation: 1627
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 134591
# 	Iterations without improvement: 84
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 26.27s
# 	Generation: 1663
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 137531
# 	Iterations without improvement: 120
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 27.27s
# 	Generation: 1698
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 140448
# 	Iterations without improvement: 155
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 28.3s
# 	Generation: 1733
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 143329
# 	Iterations without improvement: 190
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 29.33s
# 	Generation: 1768
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 146233
# 	Iterations without improvement: 225
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 30.36s
# 	Generation: 1802
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 149058
# 	Iterations without improvement: 259
# 	Substrate probability:
# 		DE/rand/1:           0.022796
# 		DE/best/2:           0.957342
# 		DE/current-to-best/1:0.014955
# 		DE/current-to-rand/1:0.004906
#
# Optimizing Noisy sphere:
# 	Time Spent: 31.37s
# 	Generation: 1835
# 	Best fitness: 9.123935317689747e-07
# 	Evaluations of fitness: 151785
# 	Iterations without improvement: 292
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 32.38s
# 	Generation: 1868
# 	Best fitness: 7.921575778203199e-07
# 	Evaluations of fitness: 154537
# 	Iterations without improvement: 9
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 33.39s
# 	Generation: 1900
# 	Best fitness: 7.846039237368519e-07
# 	Evaluations of fitness: 157191
# 	Iterations without improvement: 4
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 34.42s
# 	Generation: 1932
# 	Best fitness: 7.846039237368519e-07
# 	Evaluations of fitness: 159821
# 	Iterations without improvement: 36
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 35.42s
# 	Generation: 1963
# 	Best fitness: 7.595293954189955e-07
# 	Evaluations of fitness: 162380
# 	Iterations without improvement: 6
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 36.44s
# 	Generation: 1994
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 164968
# 	Iterations without improvement: 8
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 37.46s
# 	Generation: 2025
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 167542
# 	Iterations without improvement: 39
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 38.46s
# 	Generation: 2055
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 170030
# 	Iterations without improvement: 69
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 39.47s
# 	Generation: 2085
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 172523
# 	Iterations without improvement: 99
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 40.47s
# 	Generation: 2114
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 174938
# 	Iterations without improvement: 128
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 41.49s
# 	Generation: 2143
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 177349
# 	Iterations without improvement: 157
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 42.51s
# 	Generation: 2172
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 179775
# 	Iterations without improvement: 186
# 	Substrate probability:
# 		DE/rand/1:           0.98529
# 		DE/best/2:           0.004905
# 		DE/current-to-best/1:0.004902
# 		DE/current-to-rand/1:0.004902
#
# Optimizing Noisy sphere:
# 	Time Spent: 43.52s
# 	Generation: 2199
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 182025
# 	Iterations without improvement: 213
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 44.53s
# 	Generation: 2225
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 184202
# 	Iterations without improvement: 239
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 45.53s
# 	Generation: 2251
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 186355
# 	Iterations without improvement: 265
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 46.54s
# 	Generation: 2278
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 188596
# 	Iterations without improvement: 292
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 47.55s
# 	Generation: 2305
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 190812
# 	Iterations without improvement: 319
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 48.56s
# 	Generation: 2331
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 192951
# 	Iterations without improvement: 345
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 49.59s
# 	Generation: 2358
# 	Best fitness: 5.28007566851532e-07
# 	Evaluations of fitness: 195186
# 	Iterations without improvement: 372
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 50.61s
# 	Generation: 2384
# 	Best fitness: 5.006557267855384e-07
# 	Evaluations of fitness: 197349
# 	Iterations without improvement: 9
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 51.63s
# 	Generation: 2410
# 	Best fitness: 5.006557267855384e-07
# 	Evaluations of fitness: 199493
# 	Iterations without improvement: 35
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 52.65s
# 	Generation: 2436
# 	Best fitness: 5.006557267855384e-07
# 	Evaluations of fitness: 201655
# 	Iterations without improvement: 61
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 53.68s
# 	Generation: 2462
# 	Best fitness: 5.006557267855384e-07
# 	Evaluations of fitness: 203817
# 	Iterations without improvement: 87
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 54.7s
# 	Generation: 2487
# 	Best fitness: 4.874249550651892e-07
# 	Evaluations of fitness: 205887
# 	Iterations without improvement: 23
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 55.71s
# 	Generation: 2512
# 	Best fitness: 4.874249550651892e-07
# 	Evaluations of fitness: 207952
# 	Iterations without improvement: 48
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 56.74s
# 	Generation: 2537
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 210035
# 	Iterations without improvement: 0
# 	Substrate probability:
# 		DE/rand/1:           0.941348
# 		DE/best/2:           0.018493
# 		DE/current-to-best/1:0.005037
# 		DE/current-to-rand/1:0.035122
#
# Optimizing Noisy sphere:
# 	Time Spent: 57.75s
# 	Generation: 2561
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 212042
# 	Iterations without improvement: 24
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 58.79s
# 	Generation: 2585
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 214018
# 	Iterations without improvement: 48
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 59.79s
# 	Generation: 2608
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 215924
# 	Iterations without improvement: 71
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 60.8s
# 	Generation: 2631
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 217851
# 	Iterations without improvement: 94
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 61.84s
# 	Generation: 2654
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 219777
# 	Iterations without improvement: 117
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 62.85s
# 	Generation: 2676
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 221596
# 	Iterations without improvement: 139
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 63.87s
# 	Generation: 2699
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 223505
# 	Iterations without improvement: 162
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 64.9s
# 	Generation: 2722
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 225412
# 	Iterations without improvement: 185
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 65.92s
# 	Generation: 2745
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 227309
# 	Iterations without improvement: 208
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 66.95s
# 	Generation: 2768
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 229216
# 	Iterations without improvement: 231
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 67.99s
# 	Generation: 2791
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 231113
# 	Iterations without improvement: 254
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 69.02s
# 	Generation: 2814
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 233023
# 	Iterations without improvement: 277
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 70.02s
# 	Generation: 2836
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 234839
# 	Iterations without improvement: 299
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 71.04s
# 	Generation: 2858
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 236656
# 	Iterations without improvement: 321
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 72.05s
# 	Generation: 2880
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 238478
# 	Iterations without improvement: 343
# 	Substrate probability:
# 		DE/rand/1:           0.985261
# 		DE/best/2:           0.004918
# 		DE/current-to-best/1:0.004904
# 		DE/current-to-rand/1:0.004916
#
# Optimizing Noisy sphere:
# 	Time Spent: 73.09s
# 	Generation: 2902
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 240287
# 	Iterations without improvement: 365
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 74.09s
# 	Generation: 2923
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 242010
# 	Iterations without improvement: 386
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 75.12s
# 	Generation: 2945
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 243841
# 	Iterations without improvement: 408
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 76.16s
# 	Generation: 2967
# 	Best fitness: 4.5222744185192986e-07
# 	Evaluations of fitness: 245658
# 	Iterations without improvement: 430
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 77.17s
# 	Generation: 2988
# 	Best fitness: 4.467938153855016e-07
# 	Evaluations of fitness: 247397
# 	Iterations without improvement: 9
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 78.21s
# 	Generation: 3010
# 	Best fitness: 4.467938153855016e-07
# 	Evaluations of fitness: 249211
# 	Iterations without improvement: 31
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 79.22s
# 	Generation: 3031
# 	Best fitness: 4.467938153855016e-07
# 	Evaluations of fitness: 250948
# 	Iterations without improvement: 52
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 80.25s
# 	Generation: 3052
# 	Best fitness: 4.467938153855016e-07
# 	Evaluations of fitness: 252681
# 	Iterations without improvement: 73
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 81.3s
# 	Generation: 3073
# 	Best fitness: 4.467938153855016e-07
# 	Evaluations of fitness: 254428
# 	Iterations without improvement: 94
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 82.3s
# 	Generation: 3093
# 	Best fitness: 4.3424417887340804e-07
# 	Evaluations of fitness: 256071
# 	Iterations without improvement: 4
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 83.3s
# 	Generation: 3113
# 	Best fitness: 4.3424417887340804e-07
# 	Evaluations of fitness: 257713
# 	Iterations without improvement: 24
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 84.35s
# 	Generation: 3134
# 	Best fitness: 4.3424417887340804e-07
# 	Evaluations of fitness: 259452
# 	Iterations without improvement: 45
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 85.39s
# 	Generation: 3155
# 	Best fitness: 4.3424417887340804e-07
# 	Evaluations of fitness: 261188
# 	Iterations without improvement: 66
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 86.4s
# 	Generation: 3175
# 	Best fitness: 4.3424417887340804e-07
# 	Evaluations of fitness: 262840
# 	Iterations without improvement: 86
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 87.42s
# 	Generation: 3195
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 264494
# 	Iterations without improvement: 10
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 88.45s
# 	Generation: 3215
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 266157
# 	Iterations without improvement: 30
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 89.51s
# 	Generation: 3235
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 267816
# 	Iterations without improvement: 50
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 90.52s
# 	Generation: 3254
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 269393
# 	Iterations without improvement: 69
# 	Substrate probability:
# 		DE/rand/1:           0.984032
# 		DE/best/2:           0.005961
# 		DE/current-to-best/1:0.005087
# 		DE/current-to-rand/1:0.00492
#
# Optimizing Noisy sphere:
# 	Time Spent: 91.55s
# 	Generation: 3273
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 270966
# 	Iterations without improvement: 88
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 92.59s
# 	Generation: 3292
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 272548
# 	Iterations without improvement: 107
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 93.6s
# 	Generation: 3311
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 274119
# 	Iterations without improvement: 126
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 94.62s
# 	Generation: 3330
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 275695
# 	Iterations without improvement: 145
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 95.63s
# 	Generation: 3349
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 277257
# 	Iterations without improvement: 164
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 96.67s
# 	Generation: 3368
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 278828
# 	Iterations without improvement: 183
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 97.7s
# 	Generation: 3387
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 280403
# 	Iterations without improvement: 202
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 98.71s
# 	Generation: 3406
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 281962
# 	Iterations without improvement: 221
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 99.75s
# 	Generation: 3425
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 283523
# 	Iterations without improvement: 240
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 100.78s
# 	Generation: 3444
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 285099
# 	Iterations without improvement: 259
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 101.81s
# 	Generation: 3463
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 286686
# 	Iterations without improvement: 278
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 102.86s
# 	Generation: 3482
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 288252
# 	Iterations without improvement: 297
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 103.91s
# 	Generation: 3501
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 289833
# 	Iterations without improvement: 316
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 104.95s
# 	Generation: 3520
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 291405
# 	Iterations without improvement: 335
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 105.96s
# 	Generation: 3538
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 292898
# 	Iterations without improvement: 353
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 106.98s
# 	Generation: 3556
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 294393
# 	Iterations without improvement: 371
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 108.01s
# 	Generation: 3574
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 295887
# 	Iterations without improvement: 389
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 109.03s
# 	Generation: 3592
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 297374
# 	Iterations without improvement: 407
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
#
# Optimizing Noisy sphere:
# 	Time Spent: 110.05s
# 	Generation: 3610
# 	Best fitness: 3.4535862319809745e-07
# 	Evaluations of fitness: 298865
# 	Iterations without improvement: 425
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904

# %% [markdown]
# Evaluate the best solution without noise.

# %%
objfunc.noise_level = 0
solution, fitness = cro_alg.best_solution()

# %%
solution
# Out:
# array([-4.02138081e-05, -2.02576634e-05,  1.87861262e-05,  8.56852696e-06,
#         4.05736424e-05, -8.21198121e-05, -9.41079386e-05, -3.24905658e-05,
#         8.42339345e-05, -3.30438387e-05, -6.37183845e-06, -1.13448956e-04,
#         2.82828403e-04,  5.43923033e-05,  6.72641986e-05,  2.45326923e-05,
#        -8.73039655e-05,  8.53542128e-05,  7.65454258e-05,  1.68741113e-04,
#         2.61065923e-05, -3.27464646e-05,  8.45463580e-05, -8.18662403e-05,
#        -1.04340609e-04,  5.37891632e-05, -1.99050456e-04, -2.63559976e-05,
#        -1.89038005e-04, -2.03862218e-04])

# %%
print(f"{fitness:.6g}")
# Out:
# 3.45359e-07

# %% [markdown]
# We will also be able to visualize the progress curve and the probability assiciated to each operator in each step, this will be done with the display_report method.

# %%
cro_alg.display_report()
# Out:
# Finished optimizing Noisy sphere
# Number of generations: 3625
# Real time spent: 110.91771s
# CPU time spent: 110.33124s
# Number of fitness evaluations: 300011
# 	Substrate probability:
# 		DE/rand/1:           0.984972
# 		DE/best/2:           0.005108
# 		DE/current-to-best/1:0.005016
# 		DE/current-to-rand/1:0.004904
# Best fitness: 3.4535862319809745e-07

# %% [markdown]
# If we want to store a solution into a file, we will be able to do so with the save_soluition method. It will save the vector and it's associated objective function value in a .csv file.

# %%
cro_alg.save_solution("example.csv")
